# %%
import sys
import os
# 프로젝트 루트 디렉토리를 Python 경로에 추가
project_root = os.path.abspath(os.path.join(os.getcwd()))
if project_root not in sys.path:
    sys.path.append(project_root)

# 이제 임포트 구문 실행
from src.workflows import generate_blog_sync

# 주제 정의
topic = "관절연골영양제의 효과와 선택 가이드"

# 구성 옵션 (선택사항)
# config = {
#     "search_api": "tavily",  # tavily, perplexity, exa, arxiv, pubmed, linkup, naver, google
#     "planner_provider": "openai",
#     "planner_model": "gpt-4o-mini",
#     "writer_provider": "openai",
#     "writer_model": "gpt-4o-mini",
#     "max_search_depth": 3
# }

# 네이버 API를 사용하는 경우 예제
config = {
    "search_api": "naver",
    "planner_provider": "openai",
    "planner_model": "gpt-4o-mini",
    "writer_provider": "openai", 
    "writer_model": "gpt-4o-mini",
    "max_search_depth": 3
}

# 구글 API를 사용하는 경우 예제
# config = {
#     "search_api": "google",
#     "planner_provider": "openai",
#     "planner_model": "gpt-4o-mini",
#     "writer_provider": "openai",
#     "writer_model": "gpt-4o-mini", 
#     "max_search_depth": 3
# }

# 블로그 생성 (동기 실행)
blog_content = generate_blog_sync(topic, config)
print(blog_content)

# 파일로 저장
with open("output/blog_content.md", "w", encoding="utf-8") as f:
    f.write(blog_content)

# 마크다운을 HTML로 변환
from src.core.content.formatters.markdown_formatter import convert_markdown_to_html

html_content = convert_markdown_to_html(
    blog_content, 
    theme="blue",  # purple, green, blue, orange, red, dark, teal, pink 중 선택
    output_file="output/html/blog_output.html"
)

# 다이어그램 생성
from src.core.content.generator import generate_diagram_from_text

svg_path, diagram_info = generate_diagram_from_text(
    text=blog_content,
    output_file="output/diagram/blog_diagram.svg"
)
# Out:
# ---------------------------------------------------------------------------
# InvalidUpdateError                        Traceback (most recent call last)
# Cell In[1], line 45
#      25 config = {
#      26     "search_api": "naver",
#      27     "planner_provider": "openai",
#    (...)
#      31     "max_search_depth": 3
#      32 }
#      34 # 구글 API를 사용하는 경우 예제
#      35 # config = {
#      36 #     "search_api": "google",
#    (...)
#      43
#      44 # 블로그 생성 (동기 실행)
# ---> 45 blog_content = generate_blog_sync(topic, config)
#      46 print(blog_content)
#      48 # 파일로 저장
#
# File c:\Users\mjkim\Documents\code\deep_blog\src\workflows\__init__.py:65, in generate_blog_sync(topic, config)
#      55 def generate_blog_sync(topic: str, config: Dict[str, Any] = None) -> str:
#      56     """블로그 생성의 동기 버전 API
#      57
#      58     Args:
#    (...)
#      63         생성된 블로그 콘텐츠
#      64     """
# ---> 65     return asyncio.run(generate_blog(topic, config))
#
# ...
